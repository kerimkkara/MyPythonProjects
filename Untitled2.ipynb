# %% [markdown]
# hsv çıkarma işlemi

# %%
import cv2
import numpy as np

image = cv2.imread('sayisal.jpg')
image = cv2.bilateralFilter(image,3,75,75)


hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

blur = cv2.medianBlur(hsv, 15)



# lower = np.array([21,66,37])
# upper = np.array([34,234,185])

lower = np.array([20,63,42])
upper = np.array([35,179,194])

# lower = np.array([17,67,24])
# upper = np.array([24,214,212])

mask = cv2.inRange(blur, lower, upper)

# kernel = np.ones((3,3),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 2)



# kernel = np.ones((3,3),np.uint8)
# mask = cv2.dilate(mask,kernel,iterations = 5)

# kernel = np.ones((3,3),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 6)



# kernel = np.ones((3,3),np.uint8)
# mask = cv2.dilate(mask,kernel,iterations = 2)

res = cv2.bitwise_and(image,image, mask= mask)            

cv2.imwrite('hsv.jpg',res)
cv2.imshow("mask ",mask)
cv2.imshow('stack', np.hstack([image, res]))
cv2.waitKey(0)

# %% [markdown]
# hsv ye işlem

# %%
import cv2
import numpy as np

image = cv2.imread('hsv.jpg')
image = cv2.bilateralFilter(image,3,75,75)


hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

blur = cv2.medianBlur(hsv, 15)



# lower = np.array([21,66,37])
# upper = np.array([34,234,185])

lower = np.array([20,63,42])
upper = np.array([35,179,194])

# lower = np.array([18,51,50])
# upper = np.array([28,110,159])

mask = cv2.inRange(blur, lower, upper)

# kernel = np.ones((3,3),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 2)



# kernel = np.ones((3,3),np.uint8)
# mask = cv2.dilate(mask,kernel,iterations = 5)

# kernel = np.ones((3,3),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 6)



# kernel = np.ones((3,3),np.uint8)
# mask = cv2.dilate(mask,kernel,iterations = 2)

res = cv2.bitwise_and(image,image, mask= mask)            

cv2.imwrite('mask.jpg',res)
cv2.imshow("mask ",mask)
cv2.imshow('stack', np.hstack([image, res]))
cv2.waitKey(0)

# %% [markdown]
# maske erozyon işlemi

# %%
import cv2
import numpy as np

image = cv2.imread('hsv.jpg')
image = cv2.bilateralFilter(image,3,75,75)


hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

blur = cv2.medianBlur(hsv, 15)



# lower = np.array([21,66,37])
# upper = np.array([34,234,185])

lower = np.array([20,63,42])
upper = np.array([35,179,194])

# lower = np.array([18,51,50])
# upper = np.array([28,110,159])

mask = cv2.inRange(blur, lower, upper)

kernel = np.ones((4,4),np.uint8)
mask = cv2.erode(mask,kernel,iterations = 1)



kernel = np.ones((3,3),np.uint8)
mask = cv2.dilate(mask,kernel,iterations = 1)

kernel = np.ones((3,3),np.uint8)
mask = cv2.erode(mask,kernel,iterations = 1)

# kernel = np.ones((3,3),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 6)



# kernel = np.ones((3,3),np.uint8)
# mask = cv2.dilate(mask,kernel,iterations = 2)

res = cv2.bitwise_and(image,image, mask= mask)            

cv2.imwrite('maskeroz.jpg',res)
cv2.imshow("mask ",mask)
cv2.imshow('stack', np.hstack([image, res]))
cv2.waitKey(0)

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('maskeroz.jpg')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
(thresh, output2) = cv2.threshold(gray_image, 100, 255, cv2.THRESH_BINARY)
cv2.imwrite("test.jpg",output2)
plt.imshow(output2)
plt.show()

# %% [markdown]
# maskeroz a hsv uygulandı

# %%
import cv2
import numpy as np

image = cv2.imread('maskeroz.jpg')
image = cv2.bilateralFilter(image,3,75,75)


hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

blur = cv2.medianBlur(hsv, 7)



# lower = np.array([21,66,37])
# upper = np.array([34,234,185])

lower = np.array([21,73,66])
upper = np.array([34,133,170])

# lower = np.array([18,51,50])
# upper = np.array([28,110,159])

mask = cv2.inRange(blur, lower, upper)

# kernel = np.ones((4,4),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 1)



# kernel = np.ones((3,3),np.uint8)
# mask = cv2.dilate(mask,kernel,iterations = 1)

# kernel = np.ones((3,3),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 1)

# kernel = np.ones((3,3),np.uint8)
# mask = cv2.erode(mask,kernel,iterations = 6)



# kernel = np.ones((3,3),np.uint8)
# mask = cv2.dilate(mask,kernel,iterations = 2)

res = cv2.bitwise_and(image,image, mask= mask)            

cv2.imwrite('maskerozmask.jpg',res)
cv2.imshow("mask ",mask)
cv2.imshow('stack', np.hstack([image, res]))
cv2.waitKey(0)

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

img = cv2.imread('hsv11.jpg')
img1 = cv2.imread('sayisal.jpg')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
(thresh, output2) = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY)
output2 = cv2.Canny(output2, 0, 255)
cv2.imwrite('son.jpg',output2)
plt.imshow(output2)
plt.show()

lines = cv2.HoughLinesP(output2, 1, np.pi/180,30)
for line in lines:
    x1,y1,x2,y2 = line[0]
    cv2.line(img1,(x1,y1),(x2,y2),(0,255,0),4)
plt.imshow(img1)
cv2.imwrite('son1.jpg',img1)
# Out:
# True
